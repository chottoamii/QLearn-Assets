# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install nbconvert

# %%
name = 'Hadamard Gate Intro'  # Write the name correctly as it is in the drive

# %%
root = '/content/gdrive/My Drive/Quantum Research/QLearn/Codes/'

notebook_path = root + name + '.ipynb'
html_path = root + name + '.html'

# !jupyter nbconvert --to html "$notebook_path" --output "$html_path"
# Out:
# [NbConvertApp] Converting notebook /content/gdrive/My Drive/Quantum Research/QLearn/Codes/Hadamard Gate Intro.ipynb to html
# [NbConvertApp] Writing 683241 bytes to /content/gdrive/My Drive/Quantum Research/QLearn/Codes/Hadamard Gate Intro.html
